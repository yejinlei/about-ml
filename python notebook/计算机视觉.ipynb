# %% [markdown]
# # 计算机视觉

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ## 基本图像处理

# %%
#图像IO

# %%
#视频IO

# %%
#摄像头IO
video_in = cv2.VideoCapture(0)
frame_count = 10
while video_in.isOpened() and frame_count > 0:
    frame_count -= 1 
    ret, frame = video_in.read()
    if ret:
        plt.gcf()
        plt.imshow(frame)
        plt.show()
        if (cv2.waitKey(100) == 27):
            break;
video_in.release()
